# %%
import pandas as pd
df = pd.read_csv('student_learning_behavior.csv')

# %%
df.head()
# Out:
#      Student_ID Date of Birth  Age          Name Gender   Course  \
# 0  2022-310-156     1/24/2004   22     Mohd Saud   Male  B. Tech
# 1  2022-310-234     7/20/2002   23    Zain Ahmed   Male  B. Tech
# 2  2022-310-151    11/20/2004   21    Mohd sadiq   Male  B. Tech
# 3  2022-310-137     2/20/2003   23   Mohd Farhaz   Male  B. Tech
# 4  2022-310-039     8/19/2004   21  Arish Ansari   Male  B. Tech
#
#    Year_Of_Study  Attendance_Percentage  Study_Hours_Per_Day  \
# 0           2022                     53                    7
# 1           2022                     64                    8
# 2           2022                     73                    7
# 3           2022                     90                    7
# 4           2022                     49                    7
#
#   Assignment_Submission_Rate  Class_Participation_Score   \
# 0                      93.00%                     74.00%
# 1                      69.00%                     64.00%
# 2                      69.00%                     62.00%
# 3                      83.00%                     70.00%
# 4                      74.00%                     69.00%
#
#    Internet_Usage_Hours   Social_Media_Hours   Sleep_Hours  \
# 0                     10                   11            6
# 1                     10                    7            8
# 2                      7                    8            8
# 3                      7                   11            8
# 4                     10                   12            7
#
#   Extracurricular_Activities  Stress_Level   Previous_GPA  Fail_Risk
# 0                          No           Low           78.0     Medium
# 1                          No          High           60.0        Low
# 2                          No          High           70.0        Low
# 3                         Yes          High           80.0        Low
# 4                          No        Medium           75.0     Medium

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.5.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nataliya ahmed\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading psycopg2_binary-2.9.12-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.8 MB 1.9 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/2.8 MB 5.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.9/2.8 MB 7.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.8 MB 8.5 MB/s eta 0:00:01
#    --------------------------- ------------ 1.9/2.8 MB 8.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.8 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 9.2 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.1 MB 9.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.1 MB 10.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.1 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 10.5 MB/s eta 0:00:00
# Downloading greenlet-3.5.0-cp312-cp312-win_amd64.whl (238 kB)
#    ---------------------------------------- 0.0/238.8 kB ? eta -:--:--
#    --------------------------------------- 238.8/238.8 kB 15.2 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary, greenlet, sqlalchemy
# Successfully installed greenlet-3.5.0 psycopg2-binary-2.9.12 sqlalchemy-2.0.49
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
username = "postgres"
password = "admin"
host = "localhost"
port = "5432"
database = "Student_behavior"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name = "student_data"
df.to_sql(table_name,engine,if_exists="replace", index=False)
print(f"Data Succesfully load into table '{table_name}' in database '{database}'")
# Out:
# Data Succesfully load into table 'student_data' in database 'Student_behavior'
